# %%
import scipy.io as sio 
import matplotlib.pyplot as plt
import moviepy as mpy

# %%
#run in moviepy isnt installed
#import sys
#!{sys.executable} -m pip install moviepy

# %%
stim_response = sio.loadmat('cell_29.mat')
test_struct = stim_response['export_struct']
test_struct.dtype
# Out:
# dtype([('cell_number', 'O'), ('spikes', 'O'), ('touch_matrix', 'O'), ('thetaAtBase', 'O'), ('amplitude', 'O'), ('setpoint', 'O'), ('phase', 'O')])

# %%
trial_number = 5
axs1 = plt.subplot(3,1,1)
axs1.plot(test_struct[0,0]['thetaAtBase'][:,trial_number])

axs2 = plt.subplot(3,1,2)
axs2.plot(test_struct[0,0]['amplitude'][:,trial_number])

axs3 = plt.subplot(3,1,3)
axs3.plot(test_struct[0,0]['spikes'][:,trial_number])

# %%
test_struct[0,0]['spikes'][:,0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)
