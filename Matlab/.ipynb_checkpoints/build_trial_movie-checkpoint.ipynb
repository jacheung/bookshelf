# %%
import numpy as np
import scipy.io as sio
import moviepy as mpy
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage
import matplotlib.pyplot as plt

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install moviepy

# %%
ds = sio.loadmat('cell_29.mat')['export_struct'][0,0]
ds['thetaAtBase']


duration = len(ds['spikes'])
trial = np.random.choice(ds['thetaAtBase'].shape[1],1)[0]
x = np.arange(0,len(ds['spikes']))
y = ds['thetaAtBase'][:,trial]

fig, ax = plt.subplots()
def make_frame(t):
    t_vals = np.round(np.linspace(0,4000,duration))
    ax.clear()
    ax.plot(x[:t_vals[t]],y[:t_vals[t]])
    ax.set_ylim(0, 4000)
    return mplfig_to_npimage(fig)

animation = VideoClip(make_frame, duration=40)
animation.ipython_display(fps=1, loop=True, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f0d7756c167f> in <module>
#      16     return mplfig_to_npimage(fig)
#      17
# ---> 18 animation = VideoClip(make_frame, duration=40)
#      19 animation.ipython_display(fps=1, loop=True, autoplay=True)
#
# ~\Anaconda3\lib\site-packages\moviepy\video\VideoClip.py in __init__(self, make_frame, ismask, duration, has_constant_size)
#      84         if make_frame:
#      85             self.make_frame = make_frame
# ---> 86             self.size = self.get_frame(0).shape[:2][::-1]
#      87         self.ismask = ismask
#      88         self.has_constant_size=has_constant_size
#
# <decorator-gen-137> in get_frame(self, t)
#
# ~\Anaconda3\lib\site-packages\moviepy\decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ...

# %%
x = np.linspace(-2, 2, 200)

duration = 4

fig, ax = plt.subplots()
def make_frame(t):
    k = ax.clear()
    k = ax.plot(x, np.sinc(x**2) + np.sin(x + 2*np.pi/duration * t), lw=3)
    k = ax.set_ylim(-1.5, 2.5)
    return mplfig_to_npimage(fig)

animation = VideoClip(make_frame, duration=duration)
animation.ipython_display(fps=40, loop=True, autoplay=True)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/3999 [15:28<1030:46:35, 928.16s/it, now=None]
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/160000 [11:51<31610:15:30, 711.24s/it, now=None]
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/3980 [16:09<1071:02:26, 969.02s/it, now=None]ne]
#
#
#
#
#
#
#
# t:   0%|          | 1/39990 [15:18<10197:34:37, 918.03s/it, now=None]
#
#
#
#
#
#
#
#
# t:   0%|          | 1/390 [15:15<98:56:36, 915.67s/it, now=None]
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/156000 [11:59<31182:18:02, 719.60s/it, now=None]
#
#
#
# t:   0%|          | 1/3980 [15:31<1029:05:32, 931.07s/it, now=None]
#
#
# ...

# %%
# Out:
# array([   0.,  211.,  421.,  632.,  842., 1053., 1263., 1474., 1684.,
#        1895., 2105., 2316., 2526., 2737., 2947., 3158., 3368., 3579.,
#        3789., 4000.])
