# %%
import numpy as np
import scipy.io as sio
import moviepy as mpy
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage
import matplotlib.pyplot as plt

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install moviepy

# %%
ds = sio.loadmat('cell_29.mat')['export_struct'][0,0]

trial = np.random.choice(ds['thetaAtBase'].shape[1],1)[0]
x = np.arange(0,len(ds['spikes']))
whisk_filter = ds['amplitude'][:,trial]>5
filtered_phase = ds['phase'][:,trial]
filtered_phase[whisk_filter] += 0 
y0 = ds['thetaAtBase'][:,trial]
y1 = ds['setpoint'][:,trial]
y2 = filtered_phase
y3 = ds['amplitude'][:,trial]

fig, ax = plt.subplots(4,1)
l, = ax[0].plot(x, y0, lw=2, c='k')
l1, = ax[1].plot(x, y1, lw=2, c='k')
l2, = ax[2].plot(x, y2, 'k.')
l3, = ax[3].plot(x, y3, lw=2, c='k')

labels = ['angle', 'midpoint', 'phase', 'amplitude']
for ix,k in enumerate(ax):
    ax[ix].set_xticks([])
    ax[ix].set_ylabel(labels[ix])
ax[3].set_xticks([0,1000,2000,3000,4000])
ax[3].set_xlabel("Time from trial start (ms)")
fig.tight_layout() # <- I love this function :D

# ANIMATE THE FIGURE WITH MOVIEPY
def plot_until_t(t):
    t_idx = int(round(duration*(t/10)))
    l.set_xdata(x[:t_idx])
    l.set_ydata(y0[:t_idx])
    
    l1.set_xdata(x[:t_idx])
    l1.set_ydata(y1[:t_idx])
    
    l2.set_xdata(x[:t_idx])
    l2.set_ydata(y2[:t_idx])
    
    l3.set_xdata(x[:t_idx])
    l3.set_ydata(y3[:t_idx])
    
    return mplfig_to_npimage(fig)

plotclip = VideoClip(plot_until_t, duration=10)
plotclip.ipython_display(fps=80, loop=True, autoplay=True,progress_bar=False)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/1000000 [1:22:11<1369729:07:41, 4931.03s/it, now=None]
#
#
# t:  39%|███▉      | 1555/4000 [1:20:46<02:15, 18.07it/s, now=None]
#
# t:   0%|          | 494/1000000 [1:21:27<17:37:53, 15.75it/s, now=None]
#
#
#
# ...
# t:   0%|          | 1/1000000 [1:21:46<1362971:09:18, 4906.70s/it, now=None]
#
#
#
#
# t:   0%|          | 1/4000 [1:09:17<4617:54:47, 4157.16s/it, now=None]
#
#
#
#
#
#                                                                             [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# t:   0%|          | 1/1000000 [1:22:11<1369749:59:39, 4931.10s/it, now=None]
#
#
# t:  39%|███▉      | 1555/4000 [1:20:47<02:15, 18.07it/s, now=None]
#
# t:   0%|          | 494/1000000 [1:21:28<17:37:53, 15.75it/s, now=None]
#
#
#
# ...
# t:   0%|          | 1/1000000 [1:21:46<1362988:36:14, 4906.76s/it, now=None]
#
#
#
#
# t:   0%|          | 1/4000 [1:09:17<4617:58:54, 4157.22s/it, now=None]
#
#
#
#
#
# ...

# %%
# Out:
# 23
